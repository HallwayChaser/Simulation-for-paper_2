# %% [markdown]
# # MATLAB-to-Python FFT/OFDM simulations
# This notebook runs the two Python translations and regenerates all publication figures.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd()
sys.path.insert(0, str(ROOT / 'code'))
print('Project root:', ROOT)

# %% [markdown]
# ## 8-point radix-2 DIT flow graph and numerical validation

# %%
from simulation_8_point_radix import main as run_fft8
run_fft8()

# %% [markdown]
# ## 64-subcarrier QPSK OFDM IFFT/FFT loopback

# %%
from ifft_fft_ofdm import main as run_ofdm
run_ofdm()

# %% [markdown]
# ## Existing consolidated DFT/FFT and fixed-point experiments

# %%
from consolidated_fft_simulation import main as run_consolidated
run_consolidated()
